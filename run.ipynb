# %%
# %run walk-speed.py data/left_ankle_3min.csv data/right_ankle_3min.csv output
# Out:
#              time      ax  butterworth   delta_v  velocity  displacement
# 0        0.094665  0.0000    -0.002313  0.000000  0.000000           NaN
# 1        0.116098  0.0000    -0.002267 -0.000049 -0.000049 -1.041616e-06
# 2        0.140022  0.0000    -0.002212 -0.000053 -0.000102 -2.428445e-06
# 3        0.143398  0.0000    -0.002144 -0.000007 -0.000109 -3.671263e-07
# 4        0.168948  0.0000    -0.002066 -0.000053 -0.000162 -4.126937e-06
# ...           ...     ...          ...       ...       ...           ...
# 15065  160.672968 -0.9193     1.525370  0.025162  4.189330  6.910719e-02
# 15066  160.677774 -0.9193     1.625736  0.007813  4.197144  2.017147e-02
# 15067  160.679870 -0.9193     1.719231  0.003604  4.200747  8.804766e-03
# 15068  160.714264 -2.1498     0.574622  0.019764  4.220511  1.451602e-01
# 15069  160.718462 -2.1498     0.652155  0.002738  4.223248  1.772920e-02
#
# [15070 rows x 6 columns]
# ...

# %%
# %run walk-speed.py data/left_ankle_0.08miles.csv data/right_ankle_0.12mile.csv output
