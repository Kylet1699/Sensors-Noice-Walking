# %%
# %run walk-speed.py data/left_ankle_3min.csv data/right_ankle_3min.csv output
# Out:
# c:\Users\kylet\Desktop\SFU\CMPT 353Project\cmpt353project\walk-speed.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   right['ax'] = right['ax'].apply(reverse_orientation)
# 0.010659220718030393
# 0.010659686973256354
# average left 0.000689854374049295
# average_right 0.10871647076404797
# 0.0002802606937461513
# 0.0005310687145642202
#         time_left  ax_left  time_right  ax_right  butterworth_left  \
# 0        0.094665   0.0000    0.106255    0.0000         -0.002313
# 1        0.116098   0.0000    0.109909    0.0000         -0.002267
# 2        0.140022   0.0000    0.147079    0.0000         -0.002212
# 3        0.143398   0.0000    0.150335    0.0000         -0.002144
# ...
