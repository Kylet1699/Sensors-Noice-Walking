# %%
# %run walk-speed.py data/right_ankle_3min.csv output
# Out:
#              time      ax  butterworth       delta_v      velocity  \
# 0        0.106255  0.0000    -0.000395  0.000000e+00  0.000000e+00
# 1        0.109909  0.0000    -0.000076 -2.791850e-07 -2.791850e-07
# 2        0.147079  0.0000     0.000241  8.954425e-06  8.675240e-06
# 3        0.150335  0.0000     0.000557  1.812483e-06  1.048772e-05
# 4        0.182980  0.0000     0.000870  2.840422e-05  3.889194e-05
# ...           ...     ...          ...           ...           ...
# 20417  217.721192 -0.0098     0.063845  1.732114e-04  8.802638e+00
# 20418  217.724102 -0.0098     0.060738  1.767482e-04  8.802815e+00
# 20419  217.726127 -0.0098     0.057102  1.156312e-04  8.802930e+00
# 20420  217.748414 -0.0098     0.053010  1.181439e-03  8.804112e+00
# 20421  217.770489 -0.0098     0.048545  1.071631e-03  8.805183e+00
#
#        displacement
# 0               NaN
# 1     -1.020142e-09
# 2      3.224587e-07
# 3      3.414803e-08
# 4      1.269627e-06
# ...             ...
# ...
